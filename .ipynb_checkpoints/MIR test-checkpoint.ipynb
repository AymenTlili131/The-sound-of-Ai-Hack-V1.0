# %% [markdown]
# <a href="https://colab.research.google.com/github/AymenTlili131/The-sound-of-Ai-Hack-V1.0/blob/working_proposals/MIR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install natsort
# Out:
# Requirement already satisfied: natsort in c:\users\aymen\.conda\envs\p36workshop\lib\site-packages (8.1.0)

# %%
import librosa
import matplotlib.pyplot as plt
import numpy as np
import os
from os import walk
import librosa.display
from natsort import natsorted
import pickle

# %%
path_str='./Dataset/Sweden/'
os.listdir(path_str)
# Out:
# ['23',
#  'Alesso, Zara Larsson',
#  'Ant Wan',
#  'Babblarna',
#  'BELL',
#  'Benson Boone',
#  'Beyoncé',
#  'Bolaget',
#  'Cornelia Jakobs',
#  'Dani M',
#  'De Vet Du, Bolaget',
#  'E4an',
#  'Ed Sheeran',
#  'Ed Sheeran, 1.Cuz',
#  'Einár',
#  'Elov & Beny, Sofie Svensson & Dom Där',
#  'Elton John, Dua Lipa, PNAU',
#  'estraden, Newkid',
#  'Farruko',
#  'Glass Animals',
#  'Harry Styles',
#  'HAVAL, Yasin, Manny Flaco',
#  'Henric Edström',
#  'Humlan Djojj, Josefine Götestam',
#  'Jireel',
#  'Joji',
#  'Kate Bush',
#  'Kris Winther, SuperJonny, Rapposaurus Rex, LamboLaz',
#  'Kygo, Dean Lewis',
#  'LOAM, ADAAM',
#  'Lost Frequencies, Calum Scott',
#  'Marshmello, Khalid',
#  'Medina',
#  'Miss Li',
#  'Molly Sandén',
#  'Olivia Lobato',
#  'Post Malone, Doja Cat',
#  'Sarettii',
#  'Sickan',
#  'Ted Gärdestad',
#  'Thomas Stenström',
#  'Tove Lo',
#  'Veronica Maggio',
#  'Victor Leksell',
#  'Zara Larsson']

# %%
import glob
for f in glob.glob('./Dataset/Sweden/**/*.wav', recursive=True):
    print([str(f.split("\\")[-1][3:-4])][0])
# Out:
# Bla bla (Intro)
# Words (feat. Zara Larsson)
# Komplicerat
# Babblarnas vaggvisa
# MISSFÖRSTÅTT
# In The Stars
# BREAK MY SOUL
# Kan Inte Gå
# Hold Me Closer
# Vidare
# SUPA
# Umbrella
# Shivers
# 2step (feat. 1.Cuz)
# Lilla Nisse
# Koppla av
# BUBBEL PÅ BALKONGEN
# Cold Heart - PNAU Remix
# Tusen gånger om (feat. Newkid)
# Pepas
# Heat Waves
# Late Night Talking
# As It Was
# MARIA
# Bonaqua
# Djurens vaggvisa
# MANO
# Glimpse of Us
# Running Up That Hill (A Deal With God)
# Blitzkrieg 2022 - Drammen
# Never Really Loved Me (with Dean Lewis)
# FAKKA UR
# Where Are You Now
# Numb
# In i dimman
# X
# Vi ska aldrig gå hem
# Syrener
# I Like You (A Happier Song) (with Doja Cat)
# MATADOR
# GET THE POINT
# Go
# Jag ska fånga en ängel
# Sol, vind och vatten
# Sista sommaren
# No One Dies From Love
# Välkommen in
# Hela världen är min
# Lay All Your Love On Me - Spotify Singles

# %%
#drive path
path="./Dataset/Sweden/"
audios = []

for (dirpath, dirnames, filenames) in walk(path):
    for filename in filenames:
        #if filename.endswith('_residual_16int.wav'):
            #print(filename)
        audios.append(os.path.join(dirpath, filename))
audios = natsorted(audios)
len(audios)
# Out:
# 49

# %%
audio_files = []
for audio in audios:
    #print(audio)
    x, fs = librosa.load(audio, sr= 44100)
    audio_files.append(x)
audio_files = np.array(audio_files)
print(audio_files.shape)
# Out:
# (49,)

# %%
import IPython.display as ipd
ipd.Audio(audio_files[48][:44100],rate=44100)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def extract_features(x, feature, win_length,n_mfcc, sr):
    #MIR extraction 
    hop_length = int(win_length/2)
    rms = librosa.feature.rms(x, frame_length= win_length, hop_length=hop_length, center=True)[0]
    spec_cent = librosa.feature.spectral_centroid(y= x,sr= sr,hop_length= hop_length,win_length= win_length)[0]  
    zcr = librosa.feature.zero_crossing_rate(x, frame_length= win_length, hop_length= hop_length)[0] 
    mel = librosa.power_to_db(np.abs(librosa.feature.melspectrogram(x, sr)))
    mfcc = librosa.feature.mfcc(x, sr= sr,n_mfcc= n_mfcc)
    duration = x.shape[0]/sr
    bpm = librosa.beat.tempo(x, sr= sr)[0]

    if feature == "rms":
        return rms
    if feature == "mfcc": 
        return mfcc
    if feature == "mel": 
        return mel
    if feature == "sc": 
        return spec_cent
    if feature == "zcr":
        return zcr
    if feature == "duration":
        return duration
    if feature == "bpm":
        return bpm

# %%
MFCC = []
hop_length= 1024
DURATION = 30
SR = 44100
for i in audio_files:
        MFCC.append(extract_features(i[:SR * DURATION],'mfcc',2048, n_mfcc= 13, sr= SR))
MFCC = np.array(MFCC)
print(MFCC.shape)
# Out:
# (49, 13, 2584)

# %%
features = ["rms", "sc","zcr","duration", "bpm"]
#features = ["rms","sc"]
feature_data = []
for i in features:
    for audio in audio_files[:1]:
        feature_data.append(extract_features(audio[:SR* DURATION], i, 2048, n_mfcc=13, sr= SR))

# %%
feature_data[4]
# Out:
# 135.99917763157896

# %%
import pandas as pd
#my_dict = {"rms": X, "sc","zcr","duration", "bpm"}
my_dict = {"rms": feature_data[0],
           "sc": feature_data[1],
           "zcr": feature_data[2],
           "duration": feature_data[3],
           "bpm": feature_data[4]
           }

audio_features = pd.DataFrame(my_dict)

# %%
audio_features
# Out:
#            rms           sc       zcr  duration         bpm
# 0     0.000003  9144.286657  0.000977      30.0  135.999178
# 1     0.004831  3173.277534  0.093262      30.0  135.999178
# 2     0.063757  2218.430585  0.131836      30.0  135.999178
# 3     0.101291  2086.259582  0.075684      30.0  135.999178
# 4     0.112358  1901.201499  0.072754      30.0  135.999178
# 5     0.123351  1732.745150  0.059570      30.0  135.999178
# 6     0.141980  1642.708201  0.053711      30.0  135.999178
# 7     0.137493  1653.062630  0.058594      30.0  135.999178
# 8     0.116187  1464.055238  0.047363      30.0  135.999178
# 9     0.122966  1251.065186  0.040527      30.0  135.999178
# 10    0.131386  1327.129362  0.041992      30.0  135.999178
# 11    0.121714  1318.870910  0.042480      30.0  135.999178
# 12    0.110475  1221.182632  0.039062      30.0  135.999178
# 13    0.106166  1413.747493  0.041992      30.0  135.999178
# 14    0.103736  1445.726392  0.041992      30.0  135.999178
# 15    0.088170  1347.891386  0.042480      30.0  135.999178
# 16    0.082850  1347.204570  0.046387      30.0  135.999178
# 17    0.092672  1212.956806  0.041016      30.0  135.999178
# 18    0.092955  1325.688701  0.040039      30.0  135.999178
# 19    0.091401  1342.575590  0.041016      30.0  135.999178
# 20    0.085002  1513.827400  0.049316      30.0  135.999178
# 21    0.089416  1765.079600  0.059570      30.0  135.999178
# 22    0.101390  1741.492951  0.061523      30.0  135.999178
# 23    0.106583  1640.781258  0.054199      30.0  135.999178
# 24    0.103598  1590.873955  0.049805      30.0  135.999178
# 25    0.089227  1554.673212  0.053711      30.0  135.999178
# 26    0.077240  1468.548354  0.053223      30.0  135.999178
# 27    0.071572  1452.152741  0.051270      30.0  135.999178
# 28    0.074307  1349.361661  0.042969      30.0  135.999178
# 29    0.074375  1382.999038  0.037598      30.0  135.999178
# ...        ...          ...       ...       ...         ...
# 1262  0.135453  3735.764869  0.075195      30.0  135.999178
# 1263  0.143011  3539.805394  0.067871      30.0  135.999178
# 1264  0.146345  3803.881166  0.056641      30.0  135.999178
# 1265  0.136109  3380.451889  0.057617      30.0  135.999178
# 1266  0.136759  3403.272462  0.057617      30.0  135.999178
# 1267  0.139545  3130.620600  0.034668      30.0  135.999178
# 1268  0.145494  1996.332478  0.021484      30.0  135.999178
# 1269  0.280860  2696.039922  0.033203      30.0  135.999178
# 1270  0.357793  3495.315450  0.035645      30.0  135.999178
# 1271  0.298307  3032.189404  0.030273      30.0  135.999178
# 1272  0.264448  3138.342942  0.025391      30.0  135.999178
# 1273  0.304693  2623.465260  0.012695      30.0  135.999178
# 1274  0.325108  2735.127638  0.009277      30.0  135.999178
# 1275  0.367978  2803.574360  0.011230      30.0  135.999178
# 1276  0.379668  2442.148625  0.012695      30.0  135.999178
# 1277  0.346457  2865.177177  0.007324      30.0  135.999178
# 1278  0.279396  2768.057401  0.024414      30.0  135.999178
# 1279  0.212373  3579.155562  0.047852      30.0  135.999178
# 1280  0.191295  3468.502577  0.055664      30.0  135.999178
# 1281  0.169670  3090.371834  0.061035      30.0  135.999178
# 1282  0.155764  3337.301865  0.069824      30.0  135.999178
# 1283  0.135337  3535.276635  0.074219      30.0  135.999178
# 1284  0.138867  2345.002248  0.042969      30.0  135.999178
# 1285  0.133087  1363.880450  0.019043      30.0  135.999178
# 1286  0.101844  1374.753728  0.027344      30.0  135.999178
# 1287  0.091024  1493.229019  0.028809      30.0  135.999178
# 1288  0.163836  3279.279528  0.090820      30.0  135.999178
# 1289  0.171240  4579.144561  0.151367      30.0  135.999178
# 1290  0.142920  3485.832258  0.101074      30.0  135.999178
# 1291  0.148803  3190.014764  0.061523      30.0  135.999178
#
# [1292 rows x 5 columns]

# %%
len(feature_data)
# Out:
# 5

# %%
import pandas as pd
#my_dict = {"rms": X, "sc","zcr","duration", "bpm"}
my_dict = {"rms": feature_data[0:10],
           "sc": feature_data[10:20],
           "zcr": feature_data[20:30],
           "duration": feature_data[30:40],
           "bpm": feature_data[40:50],
           }

audio_features = pd.DataFrame(my_dict)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-894a7124a4ff> in <module>
#       8            }
#       9
# ---> 10 audio_features = pd.DataFrame(my_dict)
#
# ~\.conda\envs\p36workshop\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     390                                  dtype=dtype, copy=copy)
#     391         elif isinstance(data, dict):
# --> 392             mgr = init_dict(data, index, columns, dtype=dtype)
#     393         elif isinstance(data, ma.MaskedArray):
#     394             import numpy.ma.mrecords as mrecords
#
# ~\.conda\envs\p36workshop\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     210         arrays = [data[k] for k in keys]
#     211
# --> 212     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     213
#     214
#
# ~\.conda\envs\p36workshop\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      49     # figure out the index, if necessary
#      50     if index is None:
# ---> 51         index = extract_index(arrays)
#      52     else:
#      53         index = ensure_index(index)
#
# ~\.conda\envs\p36workshop\lib\site-packages\pandas\core\internals\construction.py in extract_index(data)
#     315             lengths = list(set(raw_lengths))
#     316             if len(lengths) > 1:
# --> 317                 raise ValueError('arrays must all be same length')
#     318
#     319             if have_dicts:
#
# ValueError: arrays must all be same length

# %%
display(audio_features)
