# %%
import pandas as pd
df_India=pd.read_csv('.\\Dataset\\MIR_Sweden.csv' )
df_India
# Out:
#     Unnamed: 0                                             artist  \
# 0            0                                                 23
# 1            1                               Alesso, Zara Larsson
# 2            2                                            Ant Wan
# 3            3                                               BELL
# 4            4                                          Babblarna
# 5            5                                       Benson Boone
# 6            6                                           Beyoncé
# 7            7                                            Bolaget
# 8            8                                    Cornelia Jakobs
# 9            9                                             Dani M
# 10          10                                 De Vet Du, Bolaget
# 11          11                                               E4an
# 12          12                                         Ed Sheeran
# ...

# %%
len(df_India)
# Out:
# 49
